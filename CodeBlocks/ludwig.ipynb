# %%
# !pip install ludwig
# Out:
# ...
#      |████████████████████████████████| 174kB 2.8MB/s
# ...
#      |████████████████████████████████| 110.5MB 47kB/s
# ...
#      |████████████████████████████████| 3.8MB 46.0MB/s
# ...
#      |████████████████████████████████| 512kB 46.2MB/s
# ...
#   Created wheel for ludwig: filename=ludwig-0.2.2.4-cp36-none-any.whl size=233400 sha256=3fbc3a11e3a9fd0c78e460c80aba4e76bb4ee8489ce4bf76bdc804464639a56e
#   Stored in directory: /root/.cache/pip/wheels/50/07/b2/22f9e1cf1f1fa41d703be7f8119b2ed3a158b2e5326d52787c
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=61b3bbccea0d2780c8aba794eb71c7ed4513513b21f12b5c1f1182b07883f309
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built ludwig gast
# ...
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorboard 2.2.0
#     Uninstalling tensorboard-2.2.0:
# ...

# %%
# %time
# !ludwig experiment --data_csv train_1.csv --model_definition_file convertcsv.yaml
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 9.78 µs
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# ███████████████████████
# █ █ █ █  ▜█ █ █ █ █   █
# █ █ █ █ █ █ █ █ █ █ ███
# █ █   █ █ █ █ █ █ █ ▌ █
# █ █████ █ █ █ █ █ █ █ █
# █     █  ▟█     █ █   █
# ███████████████████████
# ludwig v0.2.2.4 - Experiment
#
# Experiment name: experiment
# Model name: run
# Output path: results/experiment_run
#
#
# ludwig_version: '0.2.2.4'
# command: ('/usr/local/bin/ludwig experiment --data_csv train_1.csv '
#  '--model_definition_file convertcsv.yaml')
# random_seed: 42
# input_data: 'train_1.csv'
# ...

# %%
! unzip test.zip
# Out:
# Archive:  test.zip
# replace test.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: test.csv

# %%
# %time
! ludwig predict --data_csv test.csv --model_path results/experiment_run/model/ --normalisation zscore
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 11.9 µs
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# usage: ludwig predict [options]
# ludwig predict: error: unrecognized arguments: --normalisation zscore

# %%
# !zip -r results.zip results_0
# Out:
#   adding: results_0/ (stored 0%)
#   adding: results_0/Class_probabilities.npy (deflated 88%)
#   adding: results_0/Class_predictions.npy (deflated 100%)
#   adding: results_0/Class_probabilities.csv (deflated 91%)
#   adding: results_0/Class_predictions.csv (deflated 100%)

# %%
from google.colab import files
files.download('results.zip')

# %%
# %time
! pip install requests
! pip install tabulate
! pip install "colorama>=0.3.8"
! pip install future
! pip install -f http://h2o-release.s3.amazonaws.com/h2o/latest_stable_Py.html h2o


import h2o
from h2o.automl import H2OAutoML

h2o.init()

# Import a sample binary outcome train/test set into H2O
train = h2o.import_file("train_1.csv")
test = h2o.import_file("test.csv")
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.77 µs
# ...
# Looking in links: http://h2o-release.s3.amazonaws.com/h2o/latest_stable_Py.html
# ...
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         3 mins 51 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.30.0.1
# H2O_cluster_version_age:    14 days, 23 hours and 53 minutes
# H2O_cluster_name:           H2O_from_python_unknownUser_epj2mt
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    2.068 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# ...

# %%
# Identify predictors and response
x = train.columns
y = "Class"
x.remove(y)

# %%
# For binary classification, response should be a factor
train[y] = train[y].asfactor()
#test[y] = test[y].asfactor()

# Run AutoML for 20 base models (limited to 1 hour max runtime by default)
aml = H2OAutoML(max_models=20, seed=1)
aml.train(x=x, y=y, training_frame=train)
# Out:
# AutoML progress: |███████████████
# 00:30:20.892: Skipping training of model GBM_5_AutoML_20200419_002920 due to exception: water.exceptions.H2OModelBuilderIllegalArgumentException: Illegal argument(s) for GBM model: GBM_5_AutoML_20200419_002920.  Details: ERRR on field: _min_rows: The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 86.0.
#
#
# █████████████████████████████████████████| 100%

# %%
lb = aml.leaderboard
preds = aml.leader.predict(test)
print(preds)
# Out:
# xgboost prediction progress: |████████████████████████████████████████████| 100%
# <table>
# <thead>
# <tr><th style="text-align: right;">  predict</th><th style="text-align: right;">      p0</th><th style="text-align: right;">      p1</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.394981</td><td style="text-align: right;">0.605019</td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.933174</td><td style="text-align: right;">0.066826</td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.237209</td><td style="text-align: right;">0.762791</td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.456418</td><td style="text-align: right;">0.543582</td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.402691</td><td style="text-align: right;">0.597309</td></tr>
# ...

# %%
# Out:
# Export File progress: |███████████████████████████████████████████████████| 100%

# %%
# !pip3 install atm
from atm import ATM

atm = ATM()

# %%
results = atm.run(train_path='train_1.csv', test_path="test.csv", class_column='Class', metric="roc_auc_micro",budget = 200)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Processing dataset train_1.csv
