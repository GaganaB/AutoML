# %%
# !pip install deap update_checker tqdm stopit
# Out:
# ...
#      |████████████████████████████████| 163kB 3.4MB/s
# ...
#   Created wheel for stopit: filename=stopit-1.1.2-cp36-none-any.whl size=11956 sha256=917117f264728bdcdb7d23e0df38a5455affbce0a0c49a820af9b05da70d7d73
#   Stored in directory: /root/.cache/pip/wheels/3c/85/2b/2580190404636bfc63e8de3dff629c03bb795021e1983a6cc7
# Successfully built stopit
# ...

# %%
# !pip install tpot
# Out:
# ...
#      |████████████████████████████████| 81kB 2.6MB/s
# ...

# %%
#from tpot import TPOTClassifier
from sklearn.model_selection import train_test_split
import pandas as pd 
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-264091d0-4be4-4a71-9f1a-fbba549d4a6b" name="files[]" multiple disabled />
#      <output id="result-264091d0-4be4-4a71-9f1a-fbba549d4a6b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train_1.csv to train_1.csv

# %%
df1 = pd.read_csv('train_1.csv')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b03d0b22-84f8-401f-b77e-3f47b3b60739" name="files[]" multiple disabled />
#      <output id="result-b03d0b22-84f8-401f-b77e-3f47b3b60739">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test.csv

# %%
df = pd.read_csv('test.csv')

# %%
tpot = TPOTClassifier(verbosity=2, max_time_mins=2, max_eval_time_mins=0.04, population_size=100)
#training_indices, validation_indices = training_indices, testing_indices = train_test_split(df1, stratify = "Class", train_size=0.75, test_size=0.25)
tpot.fit(df1, df1["Class"])
# Out:
# ...
# Generation 1 - Current best internal CV score: 1.0
#
# 2.01 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: DecisionTreeClassifier(input_matrix, criterion=entropy, max_depth=8, min_samples_leaf=8, min_samples_split=4)
# TPOTClassifier(config_dict=None, crossover_rate=0.1, cv=5,
#                disable_update_check=False, early_stop=None, generations=100,
#                max_eval_time_mins=0.04, max_time_mins=2, memory=None,
#                mutation_rate=0.9, n_jobs=1, offspring_size=None,
#                periodic_checkpoint_folder=None, population_size=100,
#                random_state=None, scoring=None, subsample=1.0, template=None,
#                use_dask=False, verbosity=2, warm_start=False)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7f8e2664-9b68-4d01-aec5-d9c2273fcdf5" name="files[]" multiple disabled />
#      <output id="result-7f8e2664-9b68-4d01-aec5-d9c2273fcdf5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving submission_example.csv to submission_example.csv

# %%
tpot.export('tpot_pipeline.py')

# %%
import pandas as pd 
x = pd.read_csv("submission_example.csv")

# %%
merged = df.merge(x, on='Id')
merged.to_csv("test_tpot.csv", index=False)

# %%
merged.describe()
# Out:
#                   Id           FNC1  ...      SBM_map75  Probability
# count  119748.000000  119748.000000  ...  119748.000000     119748.0
# mean   548841.390687       0.222926  ...       0.132346          0.0
# std    259591.430420       0.280595  ...       1.249984          0.0
# min    100004.000000      -0.727878  ...      -3.730479          0.0
# 25%    323648.250000       0.054766  ...      -0.775864          0.0
# 50%    548701.000000       0.245875  ...       0.133729          0.0
# 75%    773261.500000       0.422728  ...       1.055798          0.0
# max    999994.000000       0.754256  ...       3.519387          0.0
#
# [8 rows x 412 columns]

# %%
submission = tpot.predict(merged)

# %%
# Create the submission file
final = pd.DataFrame({'Id': x['Id'], 'Probability': submission})
final.to_csv('submission.csv', index = False)

# %%
from google.colab import files
files.download('submission.csv')

# %%
! pip3 install scikit-learn>=0.22.0
! sudo apt-get install swig
! sudo pip3 install auto-sklearn
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   swig3.0
# Suggested packages:
#   swig-doc swig-examples swig3.0-examples swig3.0-doc
# The following NEW packages will be installed:
#   swig swig3.0
# 0 upgraded, 2 newly installed, 0 to remove and 25 not upgraded.
# Need to get 1,100 kB of archives.
# After this operation, 5,822 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 swig3.0 amd64 3.0.12-1 [1,094 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 swig amd64 3.0.12-1 [6,460 B]
# Fetched 1,100 kB in 1s (1,325 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 2.)
# debconf: falling back to frontend: Readline
# ...
